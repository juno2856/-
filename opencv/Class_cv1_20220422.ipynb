# %%
# !pip install opencv_python
# opencv 깔기

# %%
import cv2
import numpy
import sys

cv2.__version__
# Out:
# '4.5.5'

# %%
img = cv2.imread('../computer_vision/fig/puppy.bmp')

# cv2.imshow('image', img)

# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
img_color = cv2.imread('../computer_vision/fig/PD_MRI.jpeg',flags = cv2.IMREAD_COLOR)
img_gray = cv2.imread('../computer_vision/fig/PD_MRI.jpeg',flags = cv2.IMREAD_GRAYSCALE)

print(type(img_color)) #numpy.array타입
print(img_color.shape) #(480,640,3)
print(img_color.dtype) #unit 8 


print(type(img_gray))
print(img_gray.shape)
print(img_gray.dtype)

cv2.imshow('image', img_gray)
cv2.imshow('image_color', img_color)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# (630, 630, 3)
# uint8
# <class 'numpy.ndarray'>
# (630, 630)
# uint8

# %%
img = cv2.imread('../computer_vision/fig/puppy.bmp', cv2.IMREAD_COLOR)

#이미지없을때!! 
if img is None:
    print('image read failed')
    sys.exit()

cv2.namedWindow('image')  #창에 이름 주기
cv2.imshow('image', img)

cv2.waitKey() #끌때 입력할 키 

cv2.destroyAllWindows() # 창 끄기

# %%
img = cv2.imread('../computer_vision/fig/puppy.bmp', cv2.IMREAD_COLOR)
print(img.shape)

if img is None:
    print('영상이 없습니다')
    sys.exit()

# #resize(src, dsize[,fx[, fy[, interpolation]]]]) - > dst 
# reduced_mri = cv2.resize(img, (300,300), interpolation = cv2.INTER_AREA) #사이즈 수정
# cv2.imwrite('../computer_vision/fig/reduced_my_brain.jpeg', reduced_mri) 
# 다른이름으로 줄어든 사진을 폴더에 저장


# cv2.imwrite('../computer_vision/fig/my_brain.jpeg', img) # 다른이름으로 사진을 폴더에 저장
    
    
cv2.namedWindow('image', cv2.WINDOW_NORMAL) # cv2.WINDOW_NORMAL 크기조정, 안쓰면 _AUTOSIZE
cv2.imshow('image', img) 

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (480, 640, 3)

# %%
img = cv2.imread('../computer_vision/fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None:
    print('go home')
    sys.exit()
    
cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
cv2.imshow('image', img)

# cv2.resize(img, (100,100), interpolation = cv2.INTER_AREA)
# cv2.imwrite('../computer_vision/fig/my_puppy.bmp', img)

while True:
    keys = cv2.waitKey()
    if keys == 113 or keys == 27: #esc: 27 # enter :13 #q : 113 아스키 코드? 
        break
        
# while True:
#     keys = cv2.waitKey()
#     if keys == odr('q'):
#         break
# cv2.waitKey()


cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
imgBGR = cv2.imread('../computer_vision/fig/puppy.bmp', cv2.IMREAD_COLOR)
imgGray = cv2.imread('../computer_vision/fig/puppy.bmp', cv2.IMREAD_GRAYSCALE)



if img is None:
    print('image read failed')
    sys.exit()

    
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB) #BGR을 RGB로 바꿈


# fig,axes = plt.subplots(1,3, figsize = (12,12))
# axes[0].imshow(imgRGB), axes[0].axis('off')
# axes[1].imshow(imgBGR), axes[1].axis('off')
# axes[2].imshow(imgGray, cmap = 'gray'), axes[2].axis('off')
# plt.show


plt.figure(figsize = (12,12))
plt.imshow(imgRGB)
plt.axis('off')
plt.show()
    
# cv2.imshow('image', img)

# while True:
#     key = cv2.waitKey()
#     if key == 27 or key ==113:
#         break

# cv2.destroyAllWindows()
