# %%
## 디지털 영상개선 평활화, 첨예화/ 원인을 모름 
## 디지털 영상복원  렌지의 굴곡률 / 원인을 알고있음
## 디지털 영상변환 푸리에 변환, 이산코사인 변환, 웨이브렛변환
## 디지털 압축 무손실 압축 : png, 손실 압축 jpg
## 화소처리 : 산출연산
## 영역처리 : 블러링, 샤프닝
## 기하학 처리 : 스케일, 회전, 이동
## 프레임 처리 : 산술연산, 논리연산

## image enhacement - image segmentation - 
## feature extraction - pattern classicification
## 원에 가까울 수록 1에 가깝다

## 아날로그 신호
## 디지털 신호 : 표본화/양자화
## 표본화 정리(sampling theory) : 최대 주파수의 두배이상을 표본화 한다
## 양자화 : 표본값을 이진데이터로 표현 (2^n)
## 영상에서의 표본화 : 밝기에 따라
## 영상좌표계 I(x,y)  opencv 
## 형열표현   M(r,c)  numpy     x = c/ y = r
## dpi = dot per inch
## 공간해상도 dpi

# %%
import numpy as np
import cv2
import sys
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
img = cv2.imread('./computer_vision/fig/puppy.bmp', cv2.IMREAD_COLOR)

if img is None:
    print('image read failed')
    sys.exit()
    
img_resize = cv2.resize(img, (400,300), interpolation = cv2.INTER_AREA)
cv2.imwirte('image_resize.png', img_resize)
    
cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
cv2.imshow('image', img)
cv2.imshow('image_resize')

while True:
    key = cv2.waitKey()
    if key == 27 or key ==113:
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13112/2381562278.py in <module>
#       6
#       7 img_resize = cv2.resize(img, (400,300), interpolation = cv2.INTER_AREA)
# ----> 8 cv2.imwirte('image_resize.png', img_resize)
#       9
#      10 cv2.namedWindow('image', cv2.WINDOW_AUTOSIZE)
#
# AttributeError: module 'cv2' has no attribute 'imwirte'

# %%
img = cv2.imread('./computer_vision/fig/puppy.bmp',1)

if img is None:
    print('img read failed')
    sys.exit()
    
cv2.imshow('image', img)

plt.figure(figsize = (8,8))
plt.imshow(img)
plt.axis('off')
plt.show()

while True:
    if cv2.waitKey() == 27:
        break
        
cv2.destroyAllWindows()

# %%
imgBGR = cv2.imread('./computer_vision/fig/puppy.bmp',1)
imgRGB = cv2.cvtColor(imgBGR,cv2.COLOR_BGR2RGB)


if img is None:
    print('img read failed')
    sys.exit()
    
cv2.imshow('image', img)

plt.figure(figsize = (8,8))
plt.imshow(imgRGB)
plt.axis('off')
plt.show()

while True:
    if cv2.waitKey() == 27:
        break
        
cv2.destroyAllWindows()

# %%
imgBGR = cv2.imread('./computer_vision/fig/puppy.bmp',1)
imgRGB = cv2.cvtColor(imgBGR,cv2.COLOR_BGR2RGB)
imgGRAY = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2GRAY)

if img is None:
    print('img read failed')
    sys.exit()
    
cv2.imshow('image', imgGRAY)

plt.figure(figsize = (8,8))
plt.imshow(imgGRAY) #,cmap = 'gray'
plt.axis('off')
plt.show()

while True:
    if cv2.waitKey() == 27:
        break
        
cv2.destroyAllWindows()

# %%
imgBGR = cv2.imread('./computer_vision/fig/puppy.bmp',1)
imgRGB = cv2.cvtColor(imgBGR,cv2.COLOR_BGR2RGB)
imgGRAY = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2GRAY)

if img is None:
    print('img read failed')
    sys.exit()
    
cv2.imshow('image', imgGRAY),
fig, axes = plt.subplots(1,3, figsize = (12,12))
# plt.figure(figsize = (8,8))
# plt.imshow(imgGRAY) #,cmap = 'gray'
# plt.axis('off')
axes[0].imshow(imgBGR),axes[0].axis('off')
axes[1].imshow(imgRGB),axes[1].axis('off')
axes[2].imshow(imgGRAY, cmap = 'gray'),axes[2].axis('off')
plt.show()

while True:
    if cv2.waitKey() == 27:
        break
        
cv2.destroyAllWindows()

# %%
#### ----- review ------

# %%
import os
import glob

# %%
## 사진 돌아가면서 보기
img_file_lists = os.listdir('./computer_vision/fig/images1/')
# img_file_lists
img_files = []
for i in img_file_lists:
    img_path = './computer_vision/fig/images1/' +i
    img_files.append(img_path)
    
print(img_files)   


cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN,
                     cv2.WINDOW_FULLSCREEN)

# for i in img_files:
#     img = cv2.imread(i)
    
#     cv2.imshow('image', img)
    
#     if cv2.waitKey(3000) == 27: #3초뒤에 사진넘어감
#         break


#무한히 돌아간다~
idx = 0
while True:
    img = cv2.imread(img_files[idx])
    
    cv2.imshow('image', img)
    
    if cv2.waitKey(300) == 27:
        break
        
    idx += 1
    
    if idx >= len(img_files):
        idx = 0



cv2.destroyAllWindows()
# Out:
# ['./computer_vision/fig/images1/jerry.png', './computer_vision/fig/images1/jerry1.png', './computer_vision/fig/images1/jerry3.png', './computer_vision/fig/images1/jerry4.png']

# %%
img_file_lists = os.listdir('./computer_vision/fig/images/')

img_files_glob = glob.glob('./computer_vision/fig/images/*jpg')
img_files_glob
# Out:
# ['./computer_vision/fig/images\\autumn_forest_park_128379_1920x1080.jpg',
#  './computer_vision/fig/images\\boat_mountains_lake_135258_1920x1080.jpg',
#  './computer_vision/fig/images\\forest_fog_trees_128751_1920x1080.jpg',
#  './computer_vision/fig/images\\pier_dock_sea_dusk_shore_118549_1920x1080.jpg',
#  './computer_vision/fig/images\\road_marking_evening_clouds_horizon_120298_1920x1080.jpg']

# %%
img1 = cv2.imread('./computer_vision/fig/fig/puppy.bmp', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('./computer_vision/fig/fig/puppy_1280_853.jpg', cv2.IMREAD_COLOR)

if img1 is None or img2 is None:
    sys.exit('image read failed')
    
# print(type(img1))  <class 'numpy.ndarray'>
# print(img1.shape)  (480, 640)
# print(img2.shape)  (853, 1280, 3)

# print(img.dtype)   uint8
# print(img2.dtype)  uint8

h,w = img1.shape
print('img1 size = {}x{}'.format(w,h))

h,w = img2.shape[:2]
print('img2 size = {}x{}'.format(w,h))
# Out:
# img1 size = 640x480
# img2 size = 1280x853

# %%
## 사진 데이터값 불러오기
img1 = cv2.imread('./computer_vision/fig/fig/puppy.bmp', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('./computer_vision/fig/fig/puppy.bmp', cv2.IMREAD_COLOR)


x = 320
y = 240

p1 = img1[y,x]
print('image ceter value = ', p1)

img1[10:100,100:200] = 255
img2[10:100,100:200] = (0,0,255)

cv2.imshow('img', img1)
cv2.imshow('img2', img2)

cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# image ceter value =  20

# %%
img1 = np.zeros((240,320,3), dtype = np.uint8) #이건 컬러의 검정색
img2 = np.ones((240,320), dtype = np.uint8)*255    #이건 흑백의 검정색/*255 하면 흰색
img3 = np.full((240,320,3),(0,255,255), dtype = np.uint8) # green + red = yellow
img4 = np.random.randint(0,255,(240,320), dtype = np.uint8) #노이즈

cv2.imshow('img1', img1)
cv2.imshow('img2', img2)
cv2.imshow('img3', img3)
cv2.imshow('img4', img4)


cv2.waitKey()
cv2.destroyAllWindows()

# %%
## 복사할때는 .copy()   !!!!!!!!!!!
img1 = cv2.imread('./computer_vision/fig/fig/puppy.bmp',1)

if img1 is None:
    pirnt('imgae read failed')
    sys.exit()
    
img2 = img1 
img3 = img1.copy()

img1[200:300, 200:400] = (0,0,255)
    
cv2.imshow('image1', img1)
cv2.imshow('image2', img2)
cv2.imshow('image3', img3)


cv2.waitKey()
cv2.destroyAllWindows()

# %%
## 구간copy
img1 = cv2.imread('./computer_vision/fig/fig/puppy.bmp',1)

img2 = img1[200:400, 300:500]
img3 = img1[200:400, 300:500].copy()


#circle(img, center, radius, color[, thickness[, lineType[, shift]]]) -> img
cv2.circle(img2, (100,100),50, (0,0,255),3)


if img1 is None:
    pirnt('imgae read failed')
    sys.exit()
    

cv2.imshow('img1', img1)
cv2.imshow('img2', img2)
cv2.imshow('img3', img3)




cv2.waitKey()
cv2.destroyAllWindows()
